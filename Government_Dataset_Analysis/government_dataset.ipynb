# %% [markdown]
# # Dataset Description:
#
# The Crime Review for October 2023 dataset contains records of various crimes reported during the month. It provides insights into crime trends by categorizing offenses under major and minor heads, helping to understand the nature and frequency of crimes.
#
# Each entry in the dataset represents a specific type of crime, along with details such as how many cases occurred this month, last month, and the same month last year. This allows for a comparative analysis of crime patterns over time.
#
# The major heads classify crimes into broader categories like Murder, Theft, and Assault, while the minor heads give further details, such as the reason behind a crime (e.g., Murder due to property disputes).
#
# This dataset is useful for tracking crime trends, identifying high-risk crime categories, and helping authorities make informed decisions for public safety and law enforcement improvements.

# %% [markdown]
# # Overview of the Dataset
#
# Total Records: 692
# Columns: 8
#
# Data Types:
# Numerical: 4 columns (Crime counts, Serial Number)
# Categorical: 3 columns (Crime categories and descriptions)
# Float: 1 column (Crime counts for the previous year)
#
# Key Columns:
# Heads of Crime: Broad classification (e.g., IPC crimes).
# MAJOR HEAD: Specific crime category (e.g., Murder).
# MINOR HEAD: Sub-categorization of the crime (e.g., Personal Vendetta).
#
# Crime Statistics:
# Current Year (Upto Review Month),
# Previous Year (Same Month),
# Previous Month,
# Current Month.
#
# This dataset tracks crime trends across different categories, allowing for year-over-year and month-over-month comparisons. Let me know if you need further analysis.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\modil\Downloads\CRIME_REVIEW_FOR_THE_MONTH_OF_OCTOBER_2023_1 (1).csv")

# %%
df
# Out:
#      Sl. No.                                     Heads of Crime  \
# 0          1                                      A - IPC Crime
# 1          2                                      A - IPC Crime
# 2          3                                      A - IPC Crime
# 3          4                                      A - IPC Crime
# 4          5                                      A - IPC Crime
# ..       ...                                                ...
# 687      688      E. CRIME AGAINST SCHEDULED CASTES /TRIBES ...
# 688      689      E. CRIME AGAINST SCHEDULED CASTES /TRIBES ...
# 689      690      E. CRIME AGAINST SCHEDULED CASTES /TRIBES ...
# 690      691      E. CRIME AGAINST SCHEDULED CASTES /TRIBES ...
# 691      692      E. CRIME AGAINST SCHEDULED CASTES /TRIBES ...
#
#                                             MAJOR HEAD  \
# 0                             Murder (Sec.302/303 IPC)
# 1                             Murder (Sec.302/303 IPC)
# ...

# %%
df.shape
# Out:
# (692, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 692 entries, 0 to 691
# Data columns (total 8 columns):
#  #   Column                                                      Non-Null Count  Dtype
# ---  ------                                                      --------------  -----
#  0   Sl. No.                                                     692 non-null    int64
#  1   Heads of Crime                                              692 non-null    object
#  2   MAJOR HEAD                                                  692 non-null    object
#  3   MINOR HEAD                                                  621 non-null    object
#  4   During the current year upto the end of month under review  692 non-null    int64
#  5   During the corresponding month of previous year             691 non-null    float64
#  6   During the previous month                                   692 non-null    int64
# ...

# %%
df.tail()
# Out:
#      Sl. No.                                     Heads of Crime  \
# 687      688      E. CRIME AGAINST SCHEDULED CASTES /TRIBES ...
# 688      689      E. CRIME AGAINST SCHEDULED CASTES /TRIBES ...
# 689      690      E. CRIME AGAINST SCHEDULED CASTES /TRIBES ...
# 690      691      E. CRIME AGAINST SCHEDULED CASTES /TRIBES ...
# 691      692      E. CRIME AGAINST SCHEDULED CASTES /TRIBES ...
#
#                                             MAJOR HEAD MINOR HEAD  \
# 687                                             Murder        NaN
# 688                                               Rape        NaN
# 689                                         Kidnapping        NaN
# 690  Offences under the Protection of Civil Rights ...        NaN
# 691  Offences under the SC & ST  (prevention of Atr...        NaN
#
#      During the current year upto the end of month under review  \
# 687                                                 76
# 688                                                222
# ...

# %%
df.plot()
plt.show()

# %%
df.columns = df.columns.str.strip()
missing_values = df.isnull().sum()

# %%
df
# Out:
#      Sl. No.                                     Heads of Crime  \
# 0          1                                      A - IPC Crime
# 1          2                                      A - IPC Crime
# 2          3                                      A - IPC Crime
# 3          4                                      A - IPC Crime
# 4          5                                      A - IPC Crime
# ..       ...                                                ...
# 687      688      E. CRIME AGAINST SCHEDULED CASTES /TRIBES ...
# 688      689      E. CRIME AGAINST SCHEDULED CASTES /TRIBES ...
# 689      690      E. CRIME AGAINST SCHEDULED CASTES /TRIBES ...
# 690      691      E. CRIME AGAINST SCHEDULED CASTES /TRIBES ...
# 691      692      E. CRIME AGAINST SCHEDULED CASTES /TRIBES ...
#
#                                             MAJOR HEAD  \
# 0                             Murder (Sec.302/303 IPC)
# 1                             Murder (Sec.302/303 IPC)
# ...

# %%
df.isnull().sum()
# Out:
# Sl. No.                                                        0
# Heads of Crime                                                 0
# MAJOR HEAD                                                     0
# MINOR HEAD                                                    71
# During the current year upto the end of month under review     0
# During the corresponding month of previous year                1
# During the previous month                                      0
# During the current month                                       0
# dtype: int64

# %%
df.describe()
# Out:
#           Sl. No.  During the current year upto the end of month under review  \
# count  692.000000                                         692.000000
# mean   346.500000                                         294.776012
# std    199.907479                                        1328.989400
# min      1.000000                                           0.000000
# 25%    173.750000                                           0.000000
# 50%    346.500000                                           3.000000
# 75%    519.250000                                          49.000000
# max    692.000000                                       17771.000000
#
#        During the corresponding month of previous year  \
# count                                       691.000000
# mean                                         23.387844
# std                                         105.367762
# min                                           0.000000
# 25%                                           0.000000
# ...

# %%
top_crimes = df["MAJOR HEAD"].value_counts().head(5)
print("Most Common Crimes:\n", top_crimes)
# Out:
# Most Common Crimes:
#  MAJOR HEAD
# KARNATAKA STATE LOCAL ACTS                                 49
# THEFT (Sec.379 to 389 IPC)                                 27
# KIDNAPPING AND ABDUCTION (Sec.360, 361, 363 to 369 IPC)    25
# DEATHS DUE TO RASHNESS/NEGLIGENCE (Sec.304(A) IPC)         25
# Murder (Sec.302/303 IPC)                                   25
# Name: count, dtype: int64

# %%
df["Crime Change"] = df["During the current month"] - df["During the previous month"]
print(df[["MAJOR HEAD", "Crime Change"]].head(10))
# Out:
#                  MAJOR HEAD  Crime Change
# 0  Murder (Sec.302/303 IPC)             0
# 1  Murder (Sec.302/303 IPC)             2
# 2  Murder (Sec.302/303 IPC)            -2
# 3  Murder (Sec.302/303 IPC)            -2
# 4  Murder (Sec.302/303 IPC)             0
# 5  Murder (Sec.302/303 IPC)            -2
# 6  Murder (Sec.302/303 IPC)             0
# 7  Murder (Sec.302/303 IPC)             0
# 8  Murder (Sec.302/303 IPC)             0
# 9  Murder (Sec.302/303 IPC)             0

# %%
highest_increase = df.loc[df["Crime Change"].idxmax()]
print("Category with Highest Crime Increase:\n", highest_increase)
# Out:
# Category with Highest Crime Increase:
#  Sl. No.                                                                            548
# Heads of Crime                                                B - SPECIAL & LOCAL LAWS
# MAJOR HEAD                                                                  Explosives
# MINOR HEAD                                                         Explosives Act 1884
# During the current year upto the end of month under review                         201
# During the corresponding month of previous year                                    2.0
# During the previous month                                                            1
# During the current month                                                           180
# Crime Change                                                                       179
# Name: 547, dtype: object

# %% [markdown]
#   # Finding the crime category with the highest increase

# %%
low_crimes = df[df["During the current month"] == 0]
print("Crime Categories with No Incidents:\n", low_crimes[["MAJOR HEAD", "MINOR HEAD"]])
# Out:
# Crime Categories with No Incidents:
#                                              MAJOR HEAD             MINOR HEAD
# 0                             Murder (Sec.302/303 IPC)               For gain
# 4                             Murder (Sec.302/303 IPC)   For dowry by burning
# 6                             Murder (Sec.302/303 IPC)     Due to Communalism
# 7                             Murder (Sec.302/303 IPC)        Due to Casteism
# 8                             Murder (Sec.302/303 IPC)  Witch Craft (Sorcery)
# ..                                                 ...                    ...
# 678     Procuration of Minor Girls - Importing of Girl                    NaN
# 679    Procuration of Minor Girls - For Other Purposes                    NaN
# 680    Selling of girls for Prostitution (Sec.372 IPC)                    NaN
# 686                         Probation of Offenders Act                    NaN
# 690  Offences under the Protection of Civil Rights ...                    NaN
# ...

# %% [markdown]
# # Crime categories with the least incidents

# %%
df["Crime Growth %"] = ((df["During the current month"] - df["During the previous month"]) / df["During the previous month"]) * 100
print(df[["MAJOR HEAD", "Crime Growth %"]].head(10))
# Out:
#                  MAJOR HEAD  Crime Growth %
# 0  Murder (Sec.302/303 IPC)             NaN
# 1  Murder (Sec.302/303 IPC)      200.000000
# 2  Murder (Sec.302/303 IPC)      -66.666667
# 3  Murder (Sec.302/303 IPC)      -66.666667
# 4  Murder (Sec.302/303 IPC)             NaN
# 5  Murder (Sec.302/303 IPC)      -50.000000
# 6  Murder (Sec.302/303 IPC)             NaN
# 7  Murder (Sec.302/303 IPC)             NaN
# 8  Murder (Sec.302/303 IPC)             NaN
# 9  Murder (Sec.302/303 IPC)             NaN

# %% [markdown]
#  # Monthly Crime Growth Percentage

# %%
plt.figure(figsize=(10, 5))
sns.lineplot(x=df.index, y=df["During the current month"], label="Current Month")
sns.lineplot(x=df.index, y=df["During the previous month"], label="Previous Month")
plt.xlabel("Crime Index")
plt.ylabel("Crime Count")
plt.title("Crime Trend Over Time")
plt.legend()
plt.show()

# %% [markdown]
# # line chart comparing crime trends for the current and previous months using Seaborn. It helps visualize how crime counts fluctuate over time.

# %%
plt.figure(figsize=(6, 6))
sns.countplot(y=df["MAJOR HEAD"], order=df["MAJOR HEAD"].value_counts().index)
plt.xlabel("Crime Count")
plt.ylabel("Major Crime Category")
plt.title("Crime Distribution by Category")
plt.show()

# %% [markdown]
# # bar chart showing the number of crimes for each major category using Seaborn. It sorts the categories by frequency

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(data=df[["During the current month", "During the previous month"]])
plt.title("Crime Count Distribution")
plt.show()

# %% [markdown]
# # explains the distribution of crime counts for the current and previous months.

# %%
plt.figure(figsize=(10, 5))
df["During the current month"].plot.hist(bins=20, color="blue", edgecolor="black", alpha=0.7)
plt.xlabel("Crime Count")
plt.title("Crime Frequency Distribution")
plt.show()

# %% [markdown]
#  # frequently different crime counts occurred in the current month.

# %%
plt.figure(figsize=(10, 5))
sns.lineplot(x=df.index, y=df["During the current month"], label="Current Month", marker="o")
sns.lineplot(x=df.index, y=df["During the previous month"], label="Previous Month", marker="s")
plt.xlabel("Crime Index")
plt.ylabel("Crime Count")
plt.title("Crime Trend Over Time")
plt.legend()
plt.show()

# %% [markdown]
# # compared to pervious months current month crime rates are more rapidly increasing

# %%
plt.figure(figsize=(8, 8))
df["MAJOR HEAD"].value_counts().plot.pie(autopct="%1.1f%%", cmap="coolwarm", startangle=90)
plt.title("Crime Distribution by Major Head")
plt.ylabel("") 
plt.show()

# %% [markdown]
# # show the percentage distribution of crimes by major category

# %%
plt.figure(figsize=(8, 5))
sns.scatterplot(x=df["During the previous month"], y=df["During the current month"])
plt.xlabel("Previous Month Crimes")
plt.ylabel("Current Month Crimes")
plt.title("Crime Comparison: Current vs Previous Month")
plt.show()

# %% [markdown]
# # Crimes are decreased compared to pervious months

# %%
sns.pairplot(df[["During the previous month", "During the current month", 
                 "During the corresponding month of previous year"]])
plt.show()

# %% [markdown]
#  # to visualize relationships between crime counts in different months.

# %%
df["MAJOR HEAD"].value_counts().head(5).plot(kind="bar")
plt.title("Top 5 Crime Categories")
plt.xlabel("Crime Type")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# # Karnataka has the more crime category compared to other crime types

# %%
numeric_df = df.select_dtypes(include=["number"])

# %%
sns.heatmap(numeric_df.corr(), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Crime Data Correlation")
plt.show()

# %% [markdown]
# # show the correlation between different numerical crime data points.
#  # Darker or lighter colors indicate stronger or weaker relationships between crime trends.

# %%
plt.pie([df["During the current month"].sum(), df["During the previous month"].sum()], 
        labels=["Current Month", "Previous Month"], autopct="%1.1f%%", startangle=90, colors=["red", "orange"])
plt.title("Crime Cases Comparison")
plt.show()

# %% [markdown]
# # Crime cases comparison we observe previous month has higher cases compared to current month

# %%
plt.figure(figsize=(7, 5))
sns.boxplot(x=df["During the current month"])
plt.title("Crime Trends - Current Month")
plt.show()

# %%
plt.figure(figsize=(7, 5))
sns.boxplot(data=df[["During the current month", "During the previous month", "During the corresponding month of previous year"]])
plt.title("Crime Data Comparison")
plt.show()

# %% [markdown]
# # Comparing of current and previous months we observe current months have crimes more

# %%
top_crimes = df.nlargest(10, "During the current month")

plt.figure(figsize=(10,5))
sns.barplot(x="During the current month", y="MAJOR HEAD", data=top_crimes, hue="MAJOR HEAD", palette="viridis", legend=False)
plt.xlabel("Number of Cases")
plt.ylabel("Crime Type")
plt.title("Top 10 Crimes This Month")
plt.show()

# %% [markdown]
# # the top 10 crimes with the highest cases in the current month

# %%
plt.figure(figsize=(8,8))
df["MAJOR HEAD"].value_counts().head(5).plot.pie(autopct="%1.1f%%", cmap="Set3")
plt.title("Top 5 Crime Categories")
plt.ylabel("")
plt.show()

# %% [markdown]
#  # the top 5 crime categories based on their frequency. It helps visualize which crimes are most common.

# %%
plt.figure(figsize=(8,5))
sns.kdeplot(df["During the current month"],color="red")
plt.xlabel("Crime Count")
plt.ylabel("Density")
plt.title("Crime Density Distribution (KDE Plot)")
plt.show()

# %% [markdown]
# # Explains the crime cont and density of the population

# %%
plt.figure(figsize=(10,5))
sns.stripplot(x="MAJOR HEAD", y="During the current month", data=df.head(20), jitter=True)
plt.xticks(rotation=45)
plt.xlabel("Crime Type")
plt.ylabel("Crime Count")
plt.title("Crime Variation (Strip Plot)")
plt.show()

# %% [markdown]
# # Each dot represents a crime case, helping visualize spread and patterns.

# %%
df["MINOR HEAD"].value_counts().head(5).plot.pie(autopct="%1.1f%%", figsize=(7,7), cmap="coolwarm")
plt.title("Top 5 Crime Motives")
plt.ylabel("")
plt.show()

# %% [markdown]
# # There are top 5 crime motives others have more frequency

# %% [markdown]
# # Conclusion
# The dataset provides a clear picture of crime trends over time by comparing the number of cases in the current month, the previous month, and the same month last year.
# It helps in understanding whether crime rates are increasing or decreasing and identifies the most frequently occurring crimes.
#
# The classification of crimes into major and minor heads allows for a deeper understanding of the causes behind each crime, such as personal conflicts, financial disputes, or revenge. This information can be useful for law enforcement agencies to take preventive measures and focus on high-priority crime categories.
# While the dataset is useful for tracking crime trends, it lacks location-based information, which could help in identifying crime-prone areas. Additional details like the time of crime, age group of offenders, and police response times would enhance crime analysis further.
