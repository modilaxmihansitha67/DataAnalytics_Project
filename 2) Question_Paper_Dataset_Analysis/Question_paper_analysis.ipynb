# %% [markdown]
# # Analysis on Question Paper Analysis

# %% [markdown]
# # Dataset Description:
# This dataset contains 86 student records, detailing their scores in different quiz assessments. It includes 7 columns, where Q1 to Q6 represent scores in six different quizzes, and the Total column shows the sum of all quiz scores for each student.
#
# Each row represents a student's performance across these quizzes. Since all values are numerical, the dataset is well-structured for analysis, such as identifying top performers, analyzing score distribution, and comparing quiz difficulty levels.

# %% [markdown]
# # Overview of the dataset :
# The Class Marks Dataset contains records of students' performance across six quizzes (Q1 to Q6) along with a Total score, which represents the sum of all quiz marks for each student. This dataset helps in analyzing students' academic performance, identifying trends in scores, and comparing quiz difficulty levels.
#
# By examining the dataset, we can determine average scores, top performers, weakest areas, and overall class performance. It can also be useful for teachers to assess student progress and make data-driven decisions for improvement.

# %%
import pandas as pd
import matplotlib.pyplot as plt
df= pd.read_csv(r"C:\Users\modil\Downloads\class_marks.csv")
df
# Out:
#     Total  Q1aM4  Q1bM6  Q2aM6  Q2bM4  Q3aM5  Q3bM5  Q4aM3  Q4bM7  Q5M10  \
# 0      37    4.0    5.0    6.0    4.0    2.0    1.0    NaN    5.0    8.0
# 1      32    4.0    3.0    4.0    3.0    NaN    NaN    3.0    6.0    9.0
# 2      33    4.0    5.0    5.0    1.0    5.0    5.0    NaN    NaN    8.0
# 3      24    4.0    6.0    6.0    3.0    2.0    2.0    NaN    NaN    NaN
# 4      36    3.0    6.0    4.0    4.0    5.0    4.0    NaN    NaN   10.0
# ..    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 81     32    3.0    6.0    3.0    4.0    5.0    3.0    NaN    NaN    NaN
# 82     27    2.0    2.0    5.0    3.0    NaN    NaN    NaN    NaN    7.0
# 83     37    4.0    6.0    6.0    2.0    NaN    NaN    NaN    NaN    9.0
# 84     28    4.0    NaN    5.0    4.0    5.0    4.0    NaN    NaN    6.0
# 85     29    4.0    6.0    NaN    NaN    NaN    NaN    3.0    5.0    7.0
#
#     Q6aM4  Q6bM6
# 0     4.0    6.0
# 1     NaN    NaN
# 2     NaN    NaN
# 3     2.0    NaN
# ...

# %%
df.shape
# Out:
# (86, 12)

# %%
df["Q1"] = df["Q1aM4"] + df["Q1bM6"]
df["Q2"] = df["Q2aM6"] + df["Q2bM4"]
df["Q3"] = df["Q3aM5"] + df["Q3bM5"]
df["Q4"] = df["Q4aM3"] + df["Q4bM7"]
df["Q5"] = df["Q5M10"]
df["Q6"] = df["Q6aM4"] + df["Q6bM6"]
df.drop(["Q1aM4", "Q1bM6","Q2aM6","Q2bM4" ,"Q3aM5" , "Q3bM5", "Q4aM3" ,"Q4bM7","Q5M10","Q6aM4","Q6bM6"], axis=1, inplace=True) 
df
# Out:
#     Total    Q1    Q2    Q3   Q4    Q5    Q6
# 0      37   9.0  10.0   3.0  NaN   8.0  10.0
# 1      32   7.0   7.0   NaN  9.0   9.0   NaN
# 2      33   9.0   6.0  10.0  NaN   8.0   NaN
# 3      24  10.0   9.0   4.0  NaN   NaN   NaN
# 4      36   9.0   8.0   9.0  NaN  10.0   NaN
# ..    ...   ...   ...   ...  ...   ...   ...
# 81     32   9.0   7.0   8.0  NaN   NaN  10.0
# 82     27   4.0   8.0   NaN  NaN   7.0   8.0
# 83     37  10.0   8.0   NaN  NaN   9.0  10.0
# 84     28   NaN   9.0   9.0  NaN   6.0   NaN
# 85     29  10.0   NaN   NaN  8.0   7.0   5.0
#
# [86 rows x 7 columns]

# %%
df.fillna(0)
# Out:
#     Total    Q1    Q2    Q3   Q4    Q5    Q6
# 0      37   9.0  10.0   3.0  0.0   8.0  10.0
# 1      32   7.0   7.0   0.0  9.0   9.0   0.0
# 2      33   9.0   6.0  10.0  0.0   8.0   0.0
# 3      24  10.0   9.0   4.0  0.0   0.0   0.0
# 4      36   9.0   8.0   9.0  0.0  10.0   0.0
# ..    ...   ...   ...   ...  ...   ...   ...
# 81     32   9.0   7.0   8.0  0.0   0.0  10.0
# 82     27   4.0   8.0   0.0  0.0   7.0   8.0
# 83     37  10.0   8.0   0.0  0.0   9.0  10.0
# 84     28   0.0   9.0   9.0  0.0   6.0   0.0
# 85     29  10.0   0.0   0.0  8.0   7.0   5.0
#
# [86 rows x 7 columns]

# %%
data_int = df.fillna(0).astype(int)

output_file_path = (r"C:\Users\modil\Downloads\class_marks.csv")
data_int.to_csv(output_file_path, index=False)
data_int.head()
# Out:
#    Total  Q1  Q2  Q3  Q4  Q5  Q6
# 0     37   9  10   3   0   8  10
# 1     32   7   7   0   9   9   0
# 2     33   9   6  10   0   8   0
# 3     24  10   9   4   0   0   0
# 4     36   9   8   9   0  10   0

# %% [markdown]
# # FLOAT VALUES ARE CONVERTED TO INTEGER VALUES

# %%
df.plot()
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.hist(df['Total'], bins=10, color='purple', edgecolor='black')
plt.title("Distribution of Total Marks", fontsize=14)
plt.xlabel("Total Marks", fontsize=12)
plt.ylabel("Number of Students", fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# # DISTRIBUTION OF TOTAL MARKS FOR ALL THE STUDENTS.

# %%
plt.hist(df['Q1'],color='orange',edgecolor='brown',bins=7)
plt.xlabel("Marks scored in Q1")
plt.ylabel("No.of students")
plt.title("Histogram of Q1")
# Out:
# Text(0.5, 1.0, 'Histogram of Q1')

# %% [markdown]
# # DISTRIBUTION OF INDIVIDUAL SUBJECT MARKS OF ALL STUDENTS

# %%
plt.hist(df["Q2"],color='violet',bins=6,edgecolor='white')
plt.xlabel("Marks scored in Q2")
plt.ylabel("No.of students")
plt.title("Histogram of Q2")
# Out:
# Text(0.5, 1.0, 'Histogram of Q2')

# %% [markdown]
# # MANY STUDENTS GOT 10 MARKS IN THE DISTRIBUTION

# %%
plt.hist(df["Q3"],color='blue',bins=6,edgecolor='black')
plt.xlabel("Marks scored in Q3")
plt.ylabel("No.of students")
plt.title("Histogram of Q3")
# Out:
# Text(0.5, 1.0, 'Histogram of Q3')

# %% [markdown]
# # MORE STUDENTS GOT 2-4 MARKS COMPARED TO OTHER

# %%
plt.hist(df["Q4"],color='black',bins=6,edgecolor='black')
plt.xlabel("Marks scored in Q4")
plt.ylabel("No.of students")
plt.title("Histogram of Q4")
# Out:
# Text(0.5, 1.0, 'Histogram of Q4')

# %% [markdown]
# # DISTRIBUTION OF STUDENT MARKS IS INCREASED CONTINUOUSLY

# %%
plt.hist(df["Q5"],color='orange',bins=6,edgecolor='black')
plt.xlabel("Marks scored in Q5")
plt.ylabel("No.of students")

plt.title("Histogram of Q5")
# Out:
# Text(0.5, 1.0, 'Histogram of Q5')

# %% [markdown]
# # Most of the students achieved a score of 5 marks, while a few performed exceptionally well, earning scores near the maximum.

# %%
df.plot.scatter(x = 'Q1', y = 'Total',color='red',s=50)
plt.title("Scatter Plot for Q1")
# Out:
# Text(0.5, 1.0, 'Scatter Plot for Q1')

# %% [markdown]
# # MAJORITY OF THE STUDENTS GOT 10 MARKS MAXIMUM

# %%
df.plot.scatter(x = 'Q2', y = 'Total',color='red',s=50)
plt.title("Scatter Plot for Q2")
# Out:
# Text(0.5, 1.0, 'Scatter Plot for Q2')

# %% [markdown]
# # MORE STUDENTS GOT MAXIMUM MARKS OF 7

# %%
df.plot.scatter(x = 'Q5', y = 'Total',color='red',s=50)
plt.title("Scatter Plot for Q5")
# Out:
# Text(0.5, 1.0, 'Scatter Plot for Q5')

# %% [markdown]
# # This visualization highlights the impact of Q1 performance on the overall total.

# %%
df.boxplot(by='Q1', column =['Total'], grid = False,color='bLACK')
plt.title("Boxplot of Q1")
plt.ylabel("Total")
plt.show()

# %% [markdown]
# # MOST OF THE STUDENTS GOT 8 MARKS NEAR MAXIMUM OF 10 MARKS

# %%
df.boxplot(by='Q5', column =['Total'], grid = False,color='purple')
plt.title("Boxplot of Q5")
plt.ylabel("Total")
plt.show()

# %% [markdown]
# # TOTAL MARKS 40 IS MAXMIUM MARKS

# %%
df.plot.line(x='Q5',y='Total',color='red')
plt.title("Line Graph of Q5")
plt.ylabel("Total")
plt.show()

# %% [markdown]
# # It identifies whether the performance in Q2 significantly impacts the total marks and highlights any anomalies in the data.

# %%
n=pd.read_csv("class_marks.csv",skiprows=70)
n
n['1.1'].plot(kind='pie',figsize=(8,10))
plt.title("Piechart of marks in Q5")
# Out:
# Text(0.5, 1.0, 'Piechart of marks in Q5')

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Conclusion :
# The dataset provides a detailed view of student performance across six quizzes, helping to evaluate individual and overall class progress. By analyzing the data, we can identify top scorers, students who need improvement, and the average performance across different quizzes.
#
# The Total column helps in ranking students based on their cumulative scores, while individual quiz scores allow for comparison of quiz difficulty levels. If there are significant variations in scores, it may indicate that some quizzes were harder than others.
#
# Overall, this dataset serves as a useful tool for academic analysis, helping teachers and students understand learning gaps, strengths, and areas for improvement. Further analysis, such as visualizations and statistical insights, can provide a deeper understanding of student performance trends.
